# %% [markdown]
# 1.Data Processing

# %%
#import dataset
import pandas as pd

# %%
data = pd.read_csv("Desktop\Edu bridge\Datas\super.csv")
data
# Out:
#     index        order_id customer_id  order_date       customer_name  \
# 0       0  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 1       1  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 2       2  CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
# 3       3  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 4       4  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 5       5  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 6       6  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7       7  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8       8  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9       9  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10     10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11     11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# ...

# %%
##duplicating purpose
new_duplicated=data[data.duplicated('customer_id')]
new_dupliacted=data[data.duplicated('customer_id')]

print('Duplicate values in customer id:') 
print(new_duplicated)
# Out:
# Duplicate values in customer id:
#     index        order_id customer_id  order_date       customer_name  \
# 1       1  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 4       4  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 6       6  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7       7  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8       8  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9       9  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10     10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11     11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 15     15  US-2015-118983    HP-14815  11/22/2015       Harold Pawlan
# 19     19  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli
# 20     20  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli
#
#          state         category sub_category     sales
# ...

# %%
data1 = pd.read_csv("Desktop\Edu bridge\Datas\products.csv")
data1
# Out:
#     index                            Product_name Product_price  \
# 0       0     REDMI 9i Sport (Coral Green, 64 GB)        ₹8,799
# 1       1   realme Narzo 50A (Oxygen Blue, 64 GB)       ₹11,499
# 2       2         realme 8i (Space Black, 128 GB)       ₹15,999
# 3       3          realme 8i (Space Black, 64 GB)       ₹13,999
# 4       4  realme Narzo 50A (Oxygen Green, 64 GB)       ₹11,499
# 5       5  realme Narzo 50A (Oxygen Blue, 128 GB)       ₹12,499
# 6       6   REDMI 9i Sport (Metallic Blue, 64 GB)        ₹8,799
# 7       7    REDMI 9i Sport (Carbon Black, 64 GB)        ₹8,799
# 8       8            APPLE iPhone SE (Red, 64 GB)       ₹27,999
# 9       9           POCO C31 (Shadow Gray, 64 GB)        ₹8,999
# 10     10        realme C21Y (Cross Black, 32 GB)        ₹9,499
# 11     11        realme C21Y (Cross Black, 64 GB)       ₹10,499
# 12     12         realme C21Y (Cross Blue, 64 GB)       ₹10,499
# 13     13            POCO C31 (Royal Blue, 32 GB)        ₹7,999
# ...

# %%
data1.head()
# Out:
#    index                            Product_name Product_price  Product_rating
# 0      0     REDMI 9i Sport (Coral Green, 64 GB)        ₹8,799             4.4
# 1      1   realme Narzo 50A (Oxygen Blue, 64 GB)       ₹11,499             4.4
# 2      2         realme 8i (Space Black, 128 GB)       ₹15,999             4.4
# 3      3          realme 8i (Space Black, 64 GB)       ₹13,999             4.5
# 4      4  realme Narzo 50A (Oxygen Green, 64 GB)       ₹11,499             4.4

# %%
data.describe()
# Out:
#            index        sales
# count  21.000000    21.000000
# mean   10.000000   341.132929
# std     6.204837   464.917033
# min     0.000000     2.544000
# 25%     5.000000    18.504000
# 50%    10.000000    68.810000
# 75%    15.000000   665.880000
# max    20.000000  1706.184000

# %%
data1.describe()
# Out:
#            index  Product_rating
# count  24.000000       24.000000
# mean   11.500000        4.425000
# std     7.071068        0.084699
# min     0.000000        4.300000
# 25%     5.750000        4.400000
# 50%    11.500000        4.400000
# 75%    17.250000        4.500000
# max    23.000000        4.600000

# %%
pd.merge(data,data1, on='index') #merging
# Out:
#     index        order_id customer_id  order_date       customer_name  \
# 0       0  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 1       1  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 2       2  CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
# 3       3  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 4       4  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 5       5  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 6       6  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7       7  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8       8  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9       9  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10     10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11     11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# ...

# %%
data.append(data1,ignore_index=False)
# Out:
#     index        order_id customer_id  order_date       customer_name  \
# 0       0  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 1       1  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 2       2  CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
# 3       3  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 4       4  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 5       5  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 6       6  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7       7  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8       8  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9       9  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10     10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11     11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# ...

# %%
#Merging of data without using merge

print(data1,data)
# Out:
#     index                            Product_name Product_price  \
# 0       0     REDMI 9i Sport (Coral Green, 64 GB)        ₹8,799
# 1       1   realme Narzo 50A (Oxygen Blue, 64 GB)       ₹11,499
# 2       2         realme 8i (Space Black, 128 GB)       ₹15,999
# 3       3          realme 8i (Space Black, 64 GB)       ₹13,999
# 4       4  realme Narzo 50A (Oxygen Green, 64 GB)       ₹11,499
# 5       5  realme Narzo 50A (Oxygen Blue, 128 GB)       ₹12,499
# 6       6   REDMI 9i Sport (Metallic Blue, 64 GB)        ₹8,799
# 7       7    REDMI 9i Sport (Carbon Black, 64 GB)        ₹8,799
# 8       8            APPLE iPhone SE (Red, 64 GB)       ₹27,999
# 9       9           POCO C31 (Shadow Gray, 64 GB)        ₹8,999
# 10     10        realme C21Y (Cross Black, 32 GB)        ₹9,499
# 11     11        realme C21Y (Cross Black, 64 GB)       ₹10,499
# 12     12         realme C21Y (Cross Blue, 64 GB)       ₹10,499
# 13     13            POCO C31 (Royal Blue, 32 GB)        ₹7,999
# ...

# %%
data
# Out:
#     index        order_id customer_id  order_date       customer_name  \
# 0       0  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 1       1  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 2       2  CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
# 3       3  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 4       4  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 5       5  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 6       6  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7       7  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8       8  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9       9  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10     10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11     11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# ...

# %%
data['category']=data['category'].map({'Furniture':2,'Office Supplies':1}).astype(float) #reshape the data by categories into number
data
# Out:
#     index        order_id customer_id  order_date       customer_name  \
# 0       0  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 1       1  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 2       2  CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
# 3       3  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 4       4  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 5       5  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 6       6  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7       7  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8       8  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9       9  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10     10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11     11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# ...

# %%
information = data1 # exsiting data modified
data=pd.DataFrame(information)
data
# Out:
#     index                            Product_name Product_price  \
# 0       0     REDMI 9i Sport (Coral Green, 64 GB)        ₹8,799
# 1       1   realme Narzo 50A (Oxygen Blue, 64 GB)       ₹11,499
# 2       2         realme 8i (Space Black, 128 GB)       ₹15,999
# 3       3          realme 8i (Space Black, 64 GB)       ₹13,999
# 4       4  realme Narzo 50A (Oxygen Green, 64 GB)       ₹11,499
# 5       5  realme Narzo 50A (Oxygen Blue, 128 GB)       ₹12,499
# 6       6   REDMI 9i Sport (Metallic Blue, 64 GB)        ₹8,799
# 7       7    REDMI 9i Sport (Carbon Black, 64 GB)        ₹8,799
# 8       8            APPLE iPhone SE (Red, 64 GB)       ₹27,999
# 9       9           POCO C31 (Shadow Gray, 64 GB)        ₹8,999
# 10     10        realme C21Y (Cross Black, 32 GB)        ₹9,499
# 11     11        realme C21Y (Cross Black, 64 GB)       ₹10,499
# 12     12         realme C21Y (Cross Blue, 64 GB)       ₹10,499
# 13     13            POCO C31 (Royal Blue, 32 GB)        ₹7,999
# ...

# %%
pd.concat([data,data1]) #concaneate
# Out:
#     index        order_id customer_id  order_date       customer_name  \
# 0       0  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 1       1  CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 2       2  CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
# 3       3  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 4       4  US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 5       5  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 6       6  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7       7  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8       8  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9       9  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10     10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11     11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# ...

# %%
grouped=data1.groupby('Product_rating')
grouped.get_group(4.4) # grouping
# Out:
#     index                            Product_name Product_price  \
# 0       0     REDMI 9i Sport (Coral Green, 64 GB)        ₹8,799
# 1       1   realme Narzo 50A (Oxygen Blue, 64 GB)       ₹11,499
# 2       2         realme 8i (Space Black, 128 GB)       ₹15,999
# 4       4  realme Narzo 50A (Oxygen Green, 64 GB)       ₹11,499
# 5       5  realme Narzo 50A (Oxygen Blue, 128 GB)       ₹12,499
# 6       6   REDMI 9i Sport (Metallic Blue, 64 GB)        ₹8,799
# 7       7    REDMI 9i Sport (Carbon Black, 64 GB)        ₹8,799
# 9       9           POCO C31 (Shadow Gray, 64 GB)        ₹8,999
# 13     13            POCO C31 (Royal Blue, 32 GB)        ₹7,999
# 19     19          realme 8 (Cyber Black, 128 GB)       ₹16,999
# 20     20         realme 8 (Cyber Silver, 128 GB)       ₹17,999
# 21     21      realme C11 2021 (Cool Grey, 32 GB)        ₹7,499
#
#     Product_rating
# 0              4.4
# 1              4.4
# 2              4.4
# 4              4.4
# 5              4.4
# ...

# %%
grouped=data.groupby('category')
grouped.get_group('Furniture') # grouping
# Out:
#     index        order_id customer_id  order_date    customer_name  \
# 0       0  CA-2016-152156    CG-12520   11/8/2016      Claire Gute
# 1       1  CA-2016-152156    CG-12520   11/8/2016      Claire Gute
# 3       3  US-2015-108966    SO-20335  10/11/2015   Sean O'Donnell
# 5       5  CA-2014-115812    BH-11710    6/9/2014  Brosina Hoffman
# 10     10  CA-2014-115812    BH-11710    6/9/2014  Brosina Hoffman
#
#          state   category sub_category      sales
# 0     Kentucky  Furniture    Bookcases   261.9600
# 1     Kentucky  Furniture       Chairs   731.9400
# 3      Florida  Furniture       Tables   957.5775
# 5   California  Furniture  Furnishings    48.8600
# 10  California  Furniture       Tables  1706.1840
