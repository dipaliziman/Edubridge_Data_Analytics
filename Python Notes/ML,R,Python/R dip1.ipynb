# %%
d=read.csv("C:/Users/Lenovo/Desktop/Edu bridge/Datas/pfizer.csv")

# %%
d
# Out:
#       org_indiv                  first_plus        first_name last_name
# 1     3-D MEDICAL SERVICES LLC   STEVEN BRUCE      STEVEN     DEITELZWEIG
# 2     AA DOCTORS, INC.           AAKASH MOHAN      AAKASH     AHUJA
# 3     ABBO, LILIAN MARGARITA     LILIAN MARGARITA  LILIAN     ABBO
# 4     ABBO, LILIAN MARGARITA     LILIAN MARGARITA  LILIAN     ABBO
# 5     ABBO, LILIAN MARGARITA     LILIAN MARGARITA  LILIAN     ABBO
# 6     ABDULLAH RAFFEE MD PC      ABDULLAH          ABDULLAH   RAFFEE
# 7     ABEBE, SHEILA Y            SHEILA Y          SHEILA     ABEBE
# 8     ABEBE, SHEILA Y            SHEILA Y          SHEILA     ABEBE
# 9     ABILENE FAMILY FOOT CENTER GALEN CHRIS       GALEN      ALBRITTON
# 10    ABOLNIK, IGOR Z            IGOR Z            IGOR       ABOLNIK
# 11    ABOLNIK, IGOR Z            IGOR Z            IGOR       ABOLNIK
# 12    ABOLNIK, IGOR Z            IGOR Z            IGOR       ABOLNIK
# ...

# %%
head(d)
# Out:
#   org_indiv                first_plus       first_name last_name   city
# 1 3-D MEDICAL SERVICES LLC STEVEN BRUCE     STEVEN     DEITELZWEIG NEW ORLEANS
# 2 AA DOCTORS, INC.         AAKASH MOHAN     AAKASH     AHUJA       PASO ROBLES
# 3 ABBO, LILIAN MARGARITA   LILIAN MARGARITA LILIAN     ABBO        MIAMI
# 4 ABBO, LILIAN MARGARITA   LILIAN MARGARITA LILIAN     ABBO        MIAMI
# 5 ABBO, LILIAN MARGARITA   LILIAN MARGARITA LILIAN     ABBO        MIAMI
# 6 ABDULLAH RAFFEE MD PC    ABDULLAH         ABDULLAH   RAFFEE      FLINT
#   state category                cash other total
# 1 LA    Professional Advising   2625   0   2625
# 2 CA    Expert-Led Forums       1000   0   1000
# 3 FL    Business Related Travel    0 448    448
# 4 FL    Meals                      0 119    119
# 5 FL    Professional Advising   1800   0   1800
# 6 MI    Expert-Led Forums        750   0    750

# %%
tail(d)
# Out:
#       org_indiv              first_plus   first_name last_name city     state
# 10082 ZUSMAN, RANDALL MARK   RANDALL MARK RANDALL    ZUSMAN    BOSTON   MA
# 10083 ZUWALLACK, RICHARD LEO RICHARD LEO  RICHARD    ZUWALLACK HARTFORD CT
# 10084 ZUWALLACK, RICHARD LEO RICHARD LEO  RICHARD    ZUWALLACK HARTFORD CT
# 10085 ZUZARTE, EDWARD        EDWARD       EDWARD     ZUZARTE   ROSEDALE MD
# 10086 ZUZARTE, EDWARD        EDWARD       EDWARD     ZUZARTE   ROSEDALE MD
# 10087 ZUZARTE, EDWARD        EDWARD       EDWARD     ZUZARTE   ROSEDALE MD
#       category                cash other total
# 10082 Meals                      0 500    500
# 10083 Expert-Led Forums       1750   0   1750
# 10084 Meals                      0  65     65
# 10085 Business Related Travel    0  61     61
# 10086 Expert-Led Forums       2000   0   2000
# 10087 Meals                      0  28     28

# %%
head(d,10)
# Out:
#    org_indiv                  first_plus       first_name last_name
# 1  3-D MEDICAL SERVICES LLC   STEVEN BRUCE     STEVEN     DEITELZWEIG
# 2  AA DOCTORS, INC.           AAKASH MOHAN     AAKASH     AHUJA
# 3  ABBO, LILIAN MARGARITA     LILIAN MARGARITA LILIAN     ABBO
# 4  ABBO, LILIAN MARGARITA     LILIAN MARGARITA LILIAN     ABBO
# 5  ABBO, LILIAN MARGARITA     LILIAN MARGARITA LILIAN     ABBO
# 6  ABDULLAH RAFFEE MD PC      ABDULLAH         ABDULLAH   RAFFEE
# 7  ABEBE, SHEILA Y            SHEILA Y         SHEILA     ABEBE
# 8  ABEBE, SHEILA Y            SHEILA Y         SHEILA     ABEBE
# 9  ABILENE FAMILY FOOT CENTER GALEN CHRIS      GALEN      ALBRITTON
# 10 ABOLNIK, IGOR Z            IGOR Z           IGOR       ABOLNIK
#    city         state category                cash other total
# 1  NEW ORLEANS  LA    Professional Advising   2625   0   2625
# 2  PASO ROBLES  CA    Expert-Led Forums       1000   0   1000
# 3  MIAMI        FL    Business Related Travel    0 448    448
# ...

# %%
tail(d,10)
# Out:
#       org_indiv              first_plus    first_name last_name city
# 10078 ZUB, DAVID WILLIAM     DAVID WILLIAM DAVID      ZUB       WINSTON SALEM
# 10079 ZUBAL, BETH ANN        BETH ANN      BETH       ZUBAL     SAINT LOUIS
# 10080 ZUBAL, BETH ANN        BETH ANN      BETH       ZUBAL     SAINT LOUIS
# 10081 ZUBAL, BETH ANN        BETH ANN      BETH       ZUBAL     SAINT LOUIS
# 10082 ZUSMAN, RANDALL MARK   RANDALL MARK  RANDALL    ZUSMAN    BOSTON
# 10083 ZUWALLACK, RICHARD LEO RICHARD LEO   RICHARD    ZUWALLACK HARTFORD
# 10084 ZUWALLACK, RICHARD LEO RICHARD LEO   RICHARD    ZUWALLACK HARTFORD
# 10085 ZUZARTE, EDWARD        EDWARD        EDWARD     ZUZARTE   ROSEDALE
# 10086 ZUZARTE, EDWARD        EDWARD        EDWARD     ZUZARTE   ROSEDALE
# 10087 ZUZARTE, EDWARD        EDWARD        EDWARD     ZUZARTE   ROSEDALE
#       state category                cash other total
# 10078 NC    Professional Advising     47   0     47
# 10079 MO    Business Related Travel    0 348    348
# ...

# %%
dim(d) #no rows
# Out:
# [1] 10087    10
