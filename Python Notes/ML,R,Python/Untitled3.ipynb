# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\Edu bridge\EDU\DATA\breast_cancer_train.csv")

# %%
df
# Out:
#           id  clump_thickness  uniform_cell_size  uniform_cell_shape  \
# 0    1000025                5                  1                   1
# 1    1002945                5                  4                   4
# 2    1015425                3                  1                   1
# 3    1016277                6                  8                   8
# 4    1017023                4                  1                   1
# ..       ...              ...                ...                 ...
# 643   776715                3                  1                   1
# 644   841769                2                  1                   1
# 645   888820                5                 10                  10
# 646   897471                4                  8                   6
# 647   897471                4                  8                   8
#
#      marginal_adhesion  single_epithelial_size bare_nuclei  bland_chromatin  \
# ...

# %%
df = df.drop(df[df["bare_nuclei"]=="?"].index,axis=0)

# %%
df["bare_nuclei"] = df["bare_nuclei"].astype(int)

# %%
df.dtypes
# Out:
# id                        int64
# clump_thickness           int64
# uniform_cell_size         int64
# uniform_cell_shape        int64
# marginal_adhesion         int64
# single_epithelial_size    int64
# bare_nuclei               int32
# bland_chromatin           int64
# normal_nucleoli           int64
# mitoses                   int64
# class                     int64
# dtype: object

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=10)
model.fit(x,y)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
val_result = pd.read_csv(r"C:\Users\Lenovo\Desktop\Edu bridge\EDU\DATA\validation_results1.csv")

# %%
val = pd.read_csv(r"C:\Users\Lenovo\Desktop\Edu bridge\EDU\DATA\breast_cancer_validation1.csv")

# %%
y_pred = model.predict(val)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
y_val = val_result.iloc[:,-1]

# %%
accuracy_score(y_val,y_pred)
# Out:
# 0.9666666666666667

# %%
confusion_matrix(y_val,y_pred)
# Out:
# array([[22,  0],
#        [ 1,  7]], dtype=int64)

# %%
result = pd.read_csv(r"C:\Users\Lenovo\Desktop\Edu bridge\EDU\DATA\breast_cancer_test.csv")

# %%
result
# Out:
#          id  clump_thickness  uniform_cell_size  uniform_cell_shape  \
# 0   1214092                1                  1                   1
# 1   1214556                3                  1                   1
# 2   1214966                9                  7                   7
# 3   1216694               10                  8                   8
# 4   1216947                1                  1                   1
# 5   1217051                5                  1                   1
# 6   1217264                1                  1                   1
# 7   1218105                5                 10                  10
# 8   1218741               10                 10                   9
# 9   1218860                1                  1                   1
# 10  1218860                1                  1                   1
# 11  1219406                5                  1                   1
# 12  1219525                8                 10                  10
# ...

# %%
#for final apply for test csv

# %%
predition = model.predict(result)

# %%
data = {"id":result["id"],"class":predition}

# %%
dataset = pd.DataFrame(data)

# %%
dataset
# Out:
#          id  class
# 0   1214092      2
# 1   1214556      2
# 2   1214966      4
# 3   1216694      4
# 4   1216947      2
# 5   1217051      2
# 6   1217264      2
# 7   1218105      4
# 8   1218741      4
# 9   1218860      2
# 10  1218860      2
# 11  1219406      2
# 12  1219525      4
# 13  1219859      4
# 14  1220330      2
# 15  1221863      4
# 16  1222047      4
# 17  1222936      4
# 18  1223282      2
# 19  1223426      2
# 20  1223793      4
# 21  1223967      2
# 22  1224329      2
# 23  1225799      4
# 24  1226012      2
# 25  1226612      4
# 26  1227210      4
# 27  1227244      2
# 28  1227481      4
# 29  1228152      4

# %%
dataset.to_csv("Submission.csv")
