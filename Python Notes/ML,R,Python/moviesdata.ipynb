# %%
## Importing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Lenovo\Desktop\Edu bridge\EDU\DATA\moviesdata.csv")

# %%
data
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# ...

# %%
## Top bottom data

# %%
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
data.tail()
# Out:
#     adult                              belongs_to_collection    budget  \
# 45  False                                                NaN  10000000
# 46  False                                                NaN  33000000
# 47  False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# 48  False                                                NaN         0
# 49  False                                                NaN   6000000
#
#                                                genres  \
# 45  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 46  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 47  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 48  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 49  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#                                              homepage     id    imdb_id  \
# 45                                                NaN  11861  tt0113347
# ...

# %%
## Data information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  50 non-null     bool
#  1   belongs_to_collection  10 non-null     object
#  2   budget                 50 non-null     int64
#  3   genres                 50 non-null     object
#  4   homepage               5 non-null      object
#  5   id                     50 non-null     int64
#  6   imdb_id                50 non-null     object
#  7   original_language      50 non-null     object
#  8   original_title         50 non-null     object
#  9   overview               49 non-null     object
#  10  popularity             50 non-null     object
#  11  poster_path            50 non-null     object
#  12  production_companies   50 non-null     object
#  13  production_countries   50 non-null     object
# ...

# %%
data.describe()
# Out:
#              budget             id     runtime   vote_count  Unnamed: 24
# count  5.000000e+01      50.000000   50.000000    50.000000          1.0
# mean   2.111700e+07   16277.100000  107.880000   690.370000         17.0
# std    2.427737e+07   23521.345145   29.633572  1253.269548          NaN
# min    0.000000e+00       5.000000    0.000000     2.000000         17.0
# 25%    0.000000e+00    1483.500000   98.250000    55.500000         17.0
# 50%    1.200000e+07    9647.000000  106.000000   199.000000         17.0
# 75%    3.231250e+07   16215.500000  121.750000   517.250000         17.0
# max    9.800000e+07  139405.000000  192.000000  5915.000000         17.0

# %%
data.describe(include='all')
# Out:
#         adult                              belongs_to_collection  \
# count      50                                                 10
# unique      1                                                 10
# top     False  {'id': 10194, 'name': 'Toy Story Collection', ...
# freq       50                                                  1
# mean      NaN                                                NaN
# std       NaN                                                NaN
# min       NaN                                                NaN
# 25%       NaN                                                NaN
# 50%       NaN                                                NaN
# 75%       NaN                                                NaN
# max       NaN                                                NaN
#
#               budget                                             genres  \
# count   5.000000e+01                                                 50
# ...

# %%
## NO of column and rows

# %%
data.shape
# Out:
# (50, 25)

# %%
data.columns
# Out:
# Index(['adult', 'budget', 'genres', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
## Data types

# %%
data.dtypes
# Out:
# adult                       bool
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# id                         int64
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                   object
# runtime                    int64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average              object
# vote_count               float64
# Unnamed: 24              float64
# dtype: object

# %%
## Checking Null values

# %%
data.isnull().sum()
# Out:
# adult                     0
# belongs_to_collection    40
# budget                    0
# genres                    0
# homepage                 45
# id                        0
# imdb_id                   0
# original_language         0
# original_title            0
# overview                  1
# popularity                0
# poster_path               0
# production_companies      0
# production_countries      0
# release_date              0
# revenue                   0
# runtime                   0
# spoken_languages          0
# status                    0
# tagline                   9
# title                     0
# video                     0
# vote_average              0
# vote_count                0
# Unnamed: 24              49
# dtype: int64

# %%
d=data.drop(["belongs_to_collection","homepage","Unnamed: 24"],axis=1,inplace=True)

# %%
data
# Out:
#     adult    budget                                             genres  \
# 0   False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2   False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3   False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4   False         0                     [{'id': 35, 'name': 'Comedy'}]
# 5   False  60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6   False  58000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7   False         0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8   False  35000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9   False  58000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10  False  62000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11  False         0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# ...
