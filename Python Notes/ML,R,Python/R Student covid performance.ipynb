# %% [markdown]
# ### Importing libraries

# %%
install.packages("readxl")
# Out:
# package 'readxl' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Lenovo\AppData\Local\Temp\Rtmp2ryqIX\downloaded_packages

# %%
install.packages("xlsx")
# Out:
# package 'xlsx' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Lenovo\AppData\Local\Temp\Rtmp2ryqIX\downloaded_packages

# %%
library(xlsx)
# Out:
# Warning message:
# "package 'xlsx' was built under R version 3.6.3"
# Error: package or namespace load failed for 'xlsx':
#  .onLoad failed in loadNamespace() for 'rJava', details:
#   call: fun(libname, pkgname)
#   error: JAVA_HOME cannot be determined from the Registry
# Traceback:
#
# 1. library(xlsx)
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps, exclude, include.only)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# ...

# %%
library(readxl)
# Out:
# Warning message:
# "package 'readxl' was built under R version 3.6.3"

# %%
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
getwd() #for without path
# Out:
# [1] "C:/Users/Lenovo/Desktop/Edu bridge/EDU/class/R PROGRAMMING"

# %% [markdown]
# ### Reading data

# %%
d=read_excel("C:/Users/Lenovo/Desktop/Edu bridge/EDU/DATA/students_c.xlsx")

# %%
d
# Out:
#      ID    Region of residence Age of Subject Time spent on Online Class
# 1    R1    Delhi-NCR           21             2
# 2    R2    Delhi-NCR           21             0
# 3    R3    Delhi-NCR           20             7
# 4    R4    Delhi-NCR           20             3
# 5    R5    Delhi-NCR           21             3
# 6    R6    Delhi-NCR           21             0
# 7    R7    Delhi-NCR           19             2
# 8    R8    Outside Delhi-NCR   19             2
# 9    R9    Delhi-NCR           21             3
# 10   R10   Outside Delhi-NCR   20             0
# 11   R11   Delhi-NCR           21             3
# 12   R12   Delhi-NCR           21             1
# 13   R13   Delhi-NCR           21             3
# 14   R14   Outside Delhi-NCR   22             1
# 15   R15   Delhi-NCR           20             5
# 16   R16   Delhi-NCR           22             3
# 17   R17   Outside Delhi-NCR   20             0
# 18   R18   Delhi-NCR           20             1
# ...

# %% [markdown]
# ### Top data

# %%
head(d)
# Out:
#   ID Region of residence Age of Subject Time spent on Online Class
# 1 R1 Delhi-NCR           21             2
# 2 R2 Delhi-NCR           21             0
# 3 R3 Delhi-NCR           20             7
# 4 R4 Delhi-NCR           20             3
# 5 R5 Delhi-NCR           21             3
# 6 R6 Delhi-NCR           21             0
#   Rating of Online Class experience Medium for online class
# 1 Good                              Laptop/Desktop
# 2 Excellent                         Smartphone
# 3 Very poor                         Laptop/Desktop
# 4 Very poor                         Smartphone
# 5 Good                              Laptop/Desktop
# 6 Very poor                         Smartphone
#   Time spent on self study Time spent on fitness Time spent on sleep
# 1 4                        0                      7
# 2 0                        2                     10
# 3 3                        0                      6
# 4 2                        1                      6
# ...

# %%
head(d,5)
# Out:
#   ID Region of residence Age of Subject Time spent on Online Class
# 1 R1 Delhi-NCR           21             2
# 2 R2 Delhi-NCR           21             0
# 3 R3 Delhi-NCR           20             7
# 4 R4 Delhi-NCR           20             3
# 5 R5 Delhi-NCR           21             3
#   Rating of Online Class experience Medium for online class
# 1 Good                              Laptop/Desktop
# 2 Excellent                         Smartphone
# 3 Very poor                         Laptop/Desktop
# 4 Very poor                         Smartphone
# 5 Good                              Laptop/Desktop
#   Time spent on self study Time spent on fitness Time spent on sleep
# 1 4                        0                      7
# 2 0                        2                     10
# 3 3                        0                      6
# 4 2                        1                      6
# 5 3                        1                      8
# ...

# %% [markdown]
# ### Last data

# %%
tail(d)
# Out:
#   ID    Region of residence Age of Subject Time spent on Online Class
# 1 R1190 Delhi-NCR           13             3
# 2 R1191 Delhi-NCR           12             3
# 3 R1192 Delhi-NCR           14             6
# 4 R1193 Delhi-NCR           13             4
# 5 R1194 Delhi-NCR           14             5
# 6 R1195 Delhi-NCR           13             5
#   Rating of Online Class experience Medium for online class
# 1 Very poor                         Smartphone
# 2 Good                              Smartphone
# 3 Average                           Smartphone
# 4 Average                           Smartphone
# 5 Excellent                         Laptop/Desktop
# 6 Good                              Tablet
#   Time spent on self study Time spent on fitness Time spent on sleep
# 1 1.0                      0.5                   8
# 2 4.0                      1.0                   8
# 3 4.0                      1.0                   9
# 4 0.0                      0.5                   8
# ...

# %%
tail(d,5)
# Out:
#   ID    Region of residence Age of Subject Time spent on Online Class
# 1 R1191 Delhi-NCR           12             3
# 2 R1192 Delhi-NCR           14             6
# 3 R1193 Delhi-NCR           13             4
# 4 R1194 Delhi-NCR           14             5
# 5 R1195 Delhi-NCR           13             5
#   Rating of Online Class experience Medium for online class
# 1 Good                              Smartphone
# 2 Average                           Smartphone
# 3 Average                           Smartphone
# 4 Excellent                         Laptop/Desktop
# 5 Good                              Tablet
#   Time spent on self study Time spent on fitness Time spent on sleep
# 1 4.0                      1.0                   8
# 2 4.0                      1.0                   9
# 3 0.0                      0.5                   8
# 4 3.5                      1.0                   8
# 5 2.0                      0.5                   7
# ...

# %% [markdown]
# ### Structure of data

# %%
str(d)
# Out:
# tibble [1,182 x 19] (S3: tbl_df/tbl/data.frame)
#  $ ID                                                                                : chr [1:1182] "R1" "R2" "R3" "R4" ...
#  $ Region of residence                                                               : chr [1:1182] "Delhi-NCR" "Delhi-NCR" "Delhi-NCR" "Delhi-NCR" ...
#  $ Age of Subject                                                                    : num [1:1182] 21 21 20 20 21 21 19 19 21 20 ...
#  $ Time spent on Online Class                                                        : num [1:1182] 2 0 7 3 3 0 2 2 3 0 ...
#  $ Rating of Online Class experience                                                 : chr [1:1182] "Good" "Excellent" "Very poor" "Very poor" ...
#  $ Medium for online class                                                           : chr [1:1182] "Laptop/Desktop" "Smartphone" "Laptop/Desktop" "Smartphone" ...
# ...

# %% [markdown]
# ### Information of data

# %%
summary(d)
# Out:
#       ID            Region of residence Age of Subject
#  Length:1182        Length:1182         Min.   : 7.00
#  Class :character   Class :character    1st Qu.:17.00
#  Mode  :character   Mode  :character    Median :20.00
#                                         Mean   :20.17
#                                         3rd Qu.:21.00
#                                         Max.   :59.00
#  Time spent on Online Class Rating of Online Class experience
#  Min.   : 0.000             Length:1182
#  1st Qu.: 2.000             Class :character
#  Median : 3.000             Mode  :character
#  Mean   : 3.209
#  3rd Qu.: 5.000
#  Max.   :10.000
#  Medium for online class Time spent on self study Time spent on fitness
#  Length:1182             Min.   : 0.000           Min.   :0.0000
#  Class :character        1st Qu.: 2.000           1st Qu.:0.0000
#  Mode  :character        Median : 2.000           Median :1.0000
#                          Mean   : 2.912           Mean   :0.7658
# ...

# %%
glimpse(d)
# Out:
# Rows: 1,182
# Columns: 19
# $ ID                                                                                   <chr> ~
# $ `Region of residence`                                                                <chr> ~
# $ `Age of Subject`                                                                     <dbl> ~
# $ `Time spent on Online Class`                                                         <dbl> ~
# $ `Rating of Online Class experience`                                                  <chr> ~
# $ `Medium for online class`                                                            <chr> ~
# $ `Time spent on self study`                                                           <dbl> ~
# $ `Time spent on fitness`                                                              <dbl> ~
# $ `Time spent on sleep`                                                                <dbl> ~
# $ `Time spent on social media`                                                         <dbl> ~
# ...

# %% [markdown]
# ### Checking null value

# %%
is.null(d)
# Out:
# [1] FALSE

# %% [markdown]
# ### Dimension

# %%
dim(d)
# Out:
# [1] 1182   19

# %%
### Extracting column

# %%
d4=d[d$Medium=="Laptop/Desktop",]
d4
# Out:
# Warning message:
# "Unknown or uninitialised column: `Medium`."
# Error: Must subset rows with a valid subscript vector.
# i Logical subscripts must match the size of the indexed input.
# x Input has size 1182 but subscript `d$Medium == "Laptop/Desktop"` has size 0.
# Traceback:
#
# 1. d[d$Medium == "Laptop/Desktop", ]
# 2. `[.tbl_df`(d, d$Medium == "Laptop/Desktop", )
# 3. tbl_subset_row(xo, i = i, i_arg)
# 4. vectbl_as_row_index(i, x, i_arg)
# 5. vectbl_as_row_location(i, nr, i_arg, assign)
# 6. subclass_row_index_errors(vec_as_location(i, n), i_arg = i_arg,
#  .     assign = assign)
# 7. withCallingHandlers(expr, vctrs_error_subscript = function(cnd) {
#  .     cnd$subscript_arg <- i_arg
#  .     cnd$subscript_elt <- "row"
#  .     if (isTRUE(assign) && !isTRUE(cnd$subscript_action %in% c("negate"))) {
#  .         cnd$subscript_action <- "assign"
#  .     }
#  .     cnd_signal(cnd)
#  . })
# 8. vec_as_location(i, n)
# 9. (function ()
# ...

# %%
### Renmae

# %%
d = rename(d,"Region"="Region of residence")

# %%
d
# Out:
#      ID    Region            Age of Subject Time spent on Online Class
# 1    R1    Delhi-NCR         21             2
# 2    R2    Delhi-NCR         21             0
# 3    R3    Delhi-NCR         20             7
# 4    R4    Delhi-NCR         20             3
# 5    R5    Delhi-NCR         21             3
# 6    R6    Delhi-NCR         21             0
# 7    R7    Delhi-NCR         19             2
# 8    R8    Outside Delhi-NCR 19             2
# 9    R9    Delhi-NCR         21             3
# 10   R10   Outside Delhi-NCR 20             0
# 11   R11   Delhi-NCR         21             3
# 12   R12   Delhi-NCR         21             1
# 13   R13   Delhi-NCR         21             3
# 14   R14   Outside Delhi-NCR 22             1
# 15   R15   Delhi-NCR         20             5
# 16   R16   Delhi-NCR         22             3
# 17   R17   Outside Delhi-NCR 20             0
# 18   R18   Delhi-NCR         20             1
# 19   R19   Delhi-NCR         21             0
# ...

# %%
### To print specify column

# %%
d1=select(d,Region,Age of subject)
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:24: unexpected symbol
# 1: d1=select(d,Region,Age of
#                            ^
# Traceback:

# %%
d1
# Out:
# Error in eval(expr, envir, enclos): object 'd1' not found
# Traceback:

# %%
### filter

# %%
d2=filter((d,Region == "Delhi-NCR"))
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:13: unexpected ','
# 1: d2=filter((d,
#                 ^
# Traceback:

# %%
d2

# %%
d3=select(d,-starts_with('T'))

# %%
d3
# Out:
#      ID    Region            Age of Subject Rating of Online Class experience
# 1    R1    Delhi-NCR         21             Good
# 2    R2    Delhi-NCR         21             Excellent
# 3    R3    Delhi-NCR         20             Very poor
# 4    R4    Delhi-NCR         20             Very poor
# 5    R5    Delhi-NCR         21             Good
# 6    R6    Delhi-NCR         21             Very poor
# 7    R7    Delhi-NCR         19             Very poor
# 8    R8    Outside Delhi-NCR 19             Very poor
# 9    R9    Delhi-NCR         21             Very poor
# 10   R10   Outside Delhi-NCR 20             Very poor
# 11   R11   Delhi-NCR         21             Good
# 12   R12   Delhi-NCR         21             Very poor
# 13   R13   Delhi-NCR         21             Average
# 14   R14   Outside Delhi-NCR 22             Good
# 15   R15   Delhi-NCR         20             Very poor
# 16   R16   Delhi-NCR         22             Average
# ...
