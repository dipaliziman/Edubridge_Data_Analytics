# %%
class Library:
    
    def __init__(self,listofbooks):
        self.availablebooks=listofbooks

    def displayAvailablebooks(self):
        print("The books we have in our library are as follows:")
        print("================================")
        for book in self.availablebooks:
            print(book)

    def deleteBook(self,requestedBook):
        if requestedBook in self.availablebooks:
            print("The book you requested has now been removed.")
            self.availablebooks.remove(requestedBook)
        else:
            print("Sorry the book you have requested to delete, is currently not in the library.")

    def addBook(self,returnedBook):
        self.availablebooks.append(returnedBook)
        print("New Book is Added Successfully.")


class Librarian:

    def delBook(self):
        print("Enter the name of the book you'd like to delete:")
        self.book=input()
        return self.book

    def newBook(self):
        print("Enter the name of the book you'd like to add:")
        self.book=input()
        return self.book

def call():
    library=Library(["Book 1","Book 2","Book 3","Book 4","Book 5"]) 
    librarian=Librarian() 
    done=False 
    while done==False:
        print(""" ======LIBRARY MENU=======
          1. Display all available books
          2. Add a book
          3. Delete a book
          4. Exit
          """)
        try:
            choice=int(input("Enter Choice:"))
            if choice==1:
                library.displayAvailablebooks()
            elif choice==2:
                library.addBook(librarian.newBook())
            elif choice==3:
                library.deleteBook(librarian.delBook())
            elif choice==4:
                break 
                            
        except:
            print("Please enter proper choice.")

call()
# Out:
#  ======LIBRARY MENU=======
#           1. Display all available books
#           2. Add a book
#           3. Delete a book
#           4. Exit
#
# Enter Choice:2
# Enter the name of the book you'd like to add:
# Python
# New Book is Added Successfully.
#  ======LIBRARY MENU=======
#           1. Display all available books
#           2. Add a book
#           3. Delete a book
#           4. Exit
#
# Enter Choice:2
# Enter the name of the book you'd like to add:
# C
# New Book is Added Successfully.
#  ======LIBRARY MENU=======
#           1. Display all available books
#           2. Add a book
#           3. Delete a book
#           4. Exit
#
# Enter Choice:1
# The books we have in our library are as follows:
# ================================
# Book 1
# Book 2
# Book 3
# Book 4
# Book 5
# Python
# C
#  ======LIBRARY MENU=======
#           1. Display all available books
#           2. Add a book
#           3. Delete a book
#           4. Exit
#
# Enter Choice:3
# Enter the name of the book you'd like to delete:
# C
# The book you requested has now been removed.
#  ======LIBRARY MENU=======
#           1. Display all available books
#           2. Add a book
#           3. Delete a book
#           4. Exit
#
# Enter Choice:1
# The books we have in our library are as follows:
# ================================
# Book 1
# Book 2
# Book 3
# Book 4
# Book 5
# Python
#  ======LIBRARY MENU=======
#           1. Display all available books
#           2. Add a book
#           3. Delete a book
#           4. Exit
#
# Enter Choice:4
